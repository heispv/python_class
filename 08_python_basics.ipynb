# %%
# We wanna install a library
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# We can check what are the preinstalled libraries in GoogleColab
# !pip list
# Out:
# Package                       Version
# ----------------------------- ----------------------------
# absl-py                       1.2.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# albumentations                1.2.1
# altair                        4.2.0
# appdirs                       1.4.4
# arviz                         0.12.1
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# async-timeout                 4.0.2
# asynctest                     0.13.0
# atari-py                      0.2.9
# atomicwrites                  1.4.1
# attrs                         22.1.0
# audioread                     3.0.0
# autograd                      1.4
# Babel                         2.10.3
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        5.0.1
# blis                          0.7.8
# ...

# %%
# How to update a library
# !pip install --upgrade numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np

# %% [markdown]
# ![Screenshot (20).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (21).png](data:image/png;base64,...)

# %%
# 0D array
zero_d = np.array(5)
zero_d
# Out:
# array(5)

# %%
# Lets check some of the modules
print(f"Shape of the array: {zero_d.shape}")
print(f"Dimension of the array: {zero_d.ndim}")
# Out:
# Shape of the array: ()
# Dimension of the array: 0

# %%
# 1D array
one_d = np.array([1, 2, 3, 4])
one_d
# Out:
# array([1, 2, 3, 4])

# %%
# Lets get some info
print(f"Shape of the array: {one_d.shape}")
print(f"Dimension of the array: {one_d.ndim}")
# Out:
# Shape of the array: (4,)
# Dimension of the array: 1

# %% [markdown]
# ![Screenshot (22).png](data:image/png;base64,...)

# %%
# 2D array
two_d = np.array([[1, 2, 3],
                  [2, 3, 4]])
two_d
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
# Get some information
print(f"Shape: {two_d.shape}")
print(f"Dimension: {two_d.ndim}")
# Out:
# Shape: (2, 3)
# Dimension: 2

# %%
# 3D array
three_d = np.array([[[1, 2, 3],
                     [4, 5, 6]],
                    [[10, 11, 12],
                     [13, 14, 15]]])
three_d
# Out:
# array([[[ 1,  2,  3],
#         [ 4,  5,  6]],
#
#        [[10, 11, 12],
#         [13, 14, 15]]])

# %%
# Check the shape
three_d.shape
# Out:
# (2, 2, 3)

# %%
# Check the dimension
three_d.ndim
# Out:
# 3

# %% [markdown]
# ![Screenshot (23).png](data:image/png;base64,...)

# %% [markdown]
# > Shapes of the arrays are very important and they should match each other.

# %%
# Example of a wrong implementation
a = np.array([[1, 2, 3, 4],
              [5, 6, 7]])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ![Screenshot (24).png](data:image/png;base64,...)

# %%
# As you can see we expected to have an 2D array, but...
print(a)
print(f"and the dimension is {a.ndim}")
# Out:
# [list([1, 2, 3, 4]) list([5, 6, 7])]
# and the dimension is 1

# %%
ex_array = np.array([1, 2, 3, 4, 5, 6])
ex_array.mean()
# Out:
# 3.5

# %%
# Summation
ex_array.sum()
# Out:
# 21

# %%
# Element wise summation
ex_array.cumsum()
# Out:
# array([ 1,  3,  6, 10, 15, 21])

# %%
ex_array
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
ex_array.argmax()
# Out:
# 5

# %%
new_ex = np.array([1, 2, 3, 20, 5, 6])
new_ex.argmax()
# Out:
# 3

# %%
new_ex[new_ex.argmax()]
# Out:
# 20

# %%
new_ex.max()
# Out:
# 20

# %%
example_tran = np.array([[1, 2, 3],
                         [4, 5, 6]])
example_tran.transpose()
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])
